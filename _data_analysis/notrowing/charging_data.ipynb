# %%
import pandas as pd

# %%
loc_df=pd.DataFrame()

# %%
loc_df = pd.read_csv("C:/Users/user/Documents/silver-car-community/_data_analysis/notrowing/전국전동휠체어급속충전기표준데이터.csv",encoding='euc-kr')

# %%
loc_df
# Out:
#              시설명   시도명 시군구명  시군구코드               소재지도로명주소  \
# 0      덕산면행정복지센터  충청북도  제천시  43150    충청북도 제천시 덕산면 약초로 59
# 1      백운면행정복지센터  충청북도  제천시  43150    충청북도 제천시 백운면 애련로 13
# 2       서면행정복지센터  충청남도  서천군  44770    충청남도 서천군 서면 서인로 761
# 3     대한노인회서천군지회  충청남도  서천군  44770   충청남도 서천군 서천읍 군청안길 27
# 4       서천국민체육센터  충청남도  서천군  44770   충청남도 서천군 마서면 마서로 400
# ...          ...   ...  ...    ...                    ...
# 4028      개진면사무소  경상북도  고령군  47830  경상북도 고령군 개진면 개경포로 967
# 4029      우곡면사무소  경상북도  고령군  47830   경상북도 고령군 우곡면 도진3길 21
# 4030    쌍림면 노인회관  경상북도  고령군  47830  경상북도 고령군 쌍림면 대가야로 616
# 4031     대가야 생활촌  경상북도  고령군  47830        고령군 대가야읍 신남로 81
# 4032       문화누리관  경상북도  고령군  47830   경상북도 고령군 대가야읍 왕릉로 30
#
#                        소재지지번주소         위도          경도    설치장소설명 평일운영시작시각  ...  \
# 0                          NaN  36.912265  128.164381      정문입구    09:00  ...
# 1                          NaN  37.137443  128.026035      정문입구    09:00  ...
# ...

# %%
loc_df.drop(['시군구코드','소재지지번주소','위도','경도','제공기관코드','제공기관명','데이터기준일자'],axis=1,inplace=True)

# %%
loc_df
# Out:
#              시설명   시도명 시군구명               소재지도로명주소    설치장소설명 평일운영시작시각  \
# 0      덕산면행정복지센터  충청북도  제천시    충청북도 제천시 덕산면 약초로 59      정문입구    09:00
# 1      백운면행정복지센터  충청북도  제천시    충청북도 제천시 백운면 애련로 13      정문입구    09:00
# 2       서면행정복지센터  충청남도  서천군    충청남도 서천군 서면 서인로 761     1층 현관    09:00
# 3     대한노인회서천군지회  충청남도  서천군   충청남도 서천군 서천읍 군청안길 27     1층 현관    09:00
# 4       서천국민체육센터  충청남도  서천군   충청남도 서천군 마서면 마서로 400     1층 현관    09:00
# ...          ...   ...  ...                    ...       ...      ...
# 4028      개진면사무소  경상북도  고령군  경상북도 고령군 개진면 개경포로 967    개진면사무소    09:00
# 4029      우곡면사무소  경상북도  고령군   경상북도 고령군 우곡면 도진3길 21    우곡면사무소    09:00
# 4030    쌍림면 노인회관  경상북도  고령군  경상북도 고령군 쌍림면 대가야로 616  쌍림면 노인회관    09:00
# 4031     대가야 생활촌  경상북도  고령군        고령군 대가야읍 신남로 81   대가야 생활촌    09:00
# 4032       문화누리관  경상북도  고령군   경상북도 고령군 대가야읍 왕릉로 30     문화누리관    09:00
#
#      평일운영종료시각 토요일운영시작시각 토요일운영종료시각 공휴일운영시작시각 공휴일운영종료시각  동시사용가능대수 공기주입가능여부  \
# ...

# %%
loc_df.to_csv("C:/Users/user/Documents/silver-car-community/_data_analysis/notrowing/charging.csv")
